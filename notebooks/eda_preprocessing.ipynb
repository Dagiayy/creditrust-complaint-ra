# %% [markdown]
# # Task 1 — EDA & Preprocessing
#
# Exploratory analysis of the raw CFPB consumer complaint export, and a
# walkthrough of the cleaning/filtering pipeline implemented in
# `src/creditrust/data/preprocessing.py` (the production version of this logic —
# this notebook calls into it rather than duplicating it, so the notebook and the
# pipeline can never silently drift apart).
#
# > Requires `data/complaints.csv` — see `data/README.md` for how to obtain it.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "src"))

import matplotlib.pyplot as plt
import pandas as pd

from creditrust.config import get_settings
from creditrust.data.preprocessing import preprocess_complaints
from creditrust.data.validation import profile_data_quality

settings = get_settings()
pd.set_option("display.max_colwidth", 120)

# %% [markdown]
# ## Load raw data and profile quality
#
# `profile_data_quality` reports null-narrative rate, duplicate rate, and the
# product distribution — the same check the CLI pipeline runs before it will
# let a preprocessing run proceed.

# %%
df = pd.read_csv(settings.raw_data_path, low_memory=False)
print(f"Loaded {len(df):,} rows, {len(df.columns)} columns")
df.head()

# %%
report = profile_data_quality(df)
report.to_dict()

# %% [markdown]
# ## Product distribution
#
# All products by complaint volume.

# %%
product_counts = df["Product"].value_counts()
print("Top 20 product types in the dataset:")
product_counts.head(20)

# %%
STRICT_PRODUCTS = [
    "Credit card",
    "Personal loan",
    "Buy Now, Pay Later (BNPL)",
    "Savings account",
    "Money transfers",
]

all_products = set(df["Product"].dropna().unique())
included_products = set(STRICT_PRODUCTS)
excluded_products = all_products - included_products

excluded_df = df[df["Product"].isin(excluded_products)]
excluded_counts = excluded_df["Product"].value_counts()
print("Top 10 excluded product types (with complaints):")
excluded_counts.head(10)

# %% [markdown]
# ## Narrative availability
#
# How much of the dataset actually has a usable complaint narrative?

# %%
has_narrative = df["Consumer complaint narrative"].notna()
print(f"{has_narrative.sum():,} / {len(df):,} rows have a narrative "
      f"({has_narrative.mean():.1%})")

fig, ax = plt.subplots(figsize=(4, 4))
has_narrative.value_counts().plot.pie(
    labels=["Has narrative", "No narrative"], autopct="%1.1f%%", ax=ax, ylabel=""
)
ax.set_title("Narrative availability")
plt.show()

# %% [markdown]
# ## Run the cleaning pipeline (strict filter)
#
# Filters to the 5 core products, drops empty/duplicate narratives, and
# normalizes text — identical logic to `scripts/run_pipeline.py preprocess`.

# %%
cleaned_strict = preprocess_complaints(df, filter_mode="strict")
print(f"Strict filter: {len(df):,} -> {len(cleaned_strict):,} cleaned complaints")
cleaned_strict[["Product", "cleaned_narrative"]].head()

# %%
cleaned_expanded = preprocess_complaints(df, filter_mode="expanded")
print(f"Expanded filter: {len(df):,} -> {len(cleaned_expanded):,} cleaned complaints")

# %% [markdown]
# ## Narrative length distribution
#
# Informs the chunk size used at embedding time.

# %%
word_counts = cleaned_strict["cleaned_narrative"].str.split().str.len()
word_counts.describe()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
word_counts.clip(upper=word_counts.quantile(0.99)).hist(bins=50, ax=ax)
ax.set_xlabel("Words per cleaned narrative (99th pct clipped)")
ax.set_ylabel("Count")
ax.set_title("Narrative length distribution — strict filter")
plt.show()

# %% [markdown]
# ## Persist outputs
#
# Writes the file `scripts/run_pipeline.py index` consumes next.

# %%
settings.filtered_data_path.parent.mkdir(parents=True, exist_ok=True)
cleaned_strict.to_csv(settings.filtered_data_path, index=False)
print(f"Saved {len(cleaned_strict):,} rows to {settings.filtered_data_path}")

# %% [markdown]
# See `notebooks/report.md` for the narrative summary of these findings.
